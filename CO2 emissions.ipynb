# %%
print('Hello world')
# Out:
# Hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1='/content/drive/MyDrive/Colab Notebooks/Assignment/EnergyForecastData.xlsx'
path2='/content/drive/MyDrive/Colab Notebooks/Assignment/Finaldraft.asv'

# %%
path1='/content/drive/MyDrive/Colab Notebooks/Assignment/EnergyForecastData.xlsx'
import pandas as pd
df=pd.read_excel(path1)
print(df)
# Out:
#     Year  Population  Annual CO2 Emissions  \
# 0   1990     4978489                630642
# 1   1991     5149496                733234
# 2   1992     5331805                788194
# 3   1993     5521761                957646
# 4   1994     5714215               1098391
# 5   1995     5905552               1117483
# 6   1996     6094272               1150830
# 7   1997     6281644               1194663
# 8   1998     6470275               1113856
# 9   1999     6664102               1461936
# 10  2000     6865946               1472928
# 11  2001     7076728               1689104
# 12  2002     7295400               2110055
# 13  2003     7520556               2393998
# 14  2004     7750003               2593600
# 15  2005     7982223               2489730
# 16  2006     8216893               3351106
# 17  2007     8454790               3930960
# 18  2008     8696915               3918994
# 19  2009     8944713               4224517
# 20  2010     9199254               4679390
# ...

# %%
df.head()
# Out:
#    Year  Population  Annual CO2 Emissions  \
# 0  1990     4978489                630642
# 1  1991     5149496                733234
# 2  1992     5331805                788194
# 3  1993     5521761                957646
# 4  1994     5714215               1098391
#
#    GDP per capita, PPP (constant 2017 international $)  \
# 0                                        2175.208576
# 1                                        2191.840607
# 2                                        2179.507230
# 3                                        2227.353200
# 4                                        2195.822052
#
#    Fossil fuels (% electricity)  Carbon Intensity  \
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
#
#    Annual CO2 emissions per unit energy (kg per kilowatt-hour)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         31 non-null     int64
#  1   Population                                                   31 non-null     int64
#  2   Annual CO2 Emissions                                         31 non-null     int64
#  3   GDP per capita, PPP (constant 2017 international $)          31 non-null     float64
#  4   Fossil fuels (% electricity)                                 21 non-null     float64
#  5   Carbon Intensity                                             21 non-null     float64
#  6   Annual CO2 emissions per unit energy (kg per kilowatt-hour)  30 non-null     float64
# dtypes: float64(4), int64(3)
# memory usage: 1.8 KB

# %%
df.describe()
# Out:
#               Year    Population  Annual CO2 Emissions  \
# count    31.000000  3.100000e+01          3.100000e+01
# mean   2005.000000  8.181586e+06          3.273598e+06
# std       9.092121  2.150550e+06          2.184713e+06
# min    1990.000000  4.978489e+06          6.306420e+05
# 25%    1997.500000  6.375960e+06          1.172746e+06
# 50%    2005.000000  7.982223e+06          2.593600e+06
# 75%    2012.500000  9.866924e+06          4.622682e+06
# max    2020.000000  1.212320e+07          7.315116e+06
#
#        GDP per capita, PPP (constant 2017 international $)  \
# count                                          31.000000
# mean                                         2627.974004
# std                                           330.452327
# min                                          2175.208576
# 25%                                          2347.413000
# 50%                                          2606.817449
# 75%                                          2818.376082
# ...
