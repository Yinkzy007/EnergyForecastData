# %% [markdown]
# <a href="https://colab.research.google.com/github/Yinkzy007/EnergyForecastData/blob/main/CO2_emissions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path1='/content/drive/MyDrive/Colab Notebooks/Assignment/EnergyForecastDataset.xlsx'
path2='/content/drive/MyDrive/Colab Notebooks/Assignment/Finaldraft.asv'

# %%
path1='/content/drive/MyDrive/Colab Notebooks/Assignment/EnergyForecastDataset.xlsx'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_excel(path1)
#df=pd.DataFrame(df)
#print(df)

# %%
df.head()
# Out:
#    Year  Population  Ann. CO2 Em.          GDP  FF (% electricity)  \
# 0  1990     4978489        630642  2175.208576                 NaN
# 1  1991     5149496        733234  2191.840607                 NaN
# 2  1992     5331805        788194  2179.507230                 NaN
# 3  1993     5521761        957646  2227.353200                 NaN
# 4  1994     5714215       1098391  2195.822052                 NaN
#
#    Carbon Intensity  Ann. CO2 Em./Unit Energy
# 0               NaN                    0.2466
# 1               NaN                    0.2454
# 2               NaN                    0.2374
# 3               NaN                    0.2623
# 4               NaN                    0.2875

# %%
#  Drop rows that contains NAN values using df.dropna()
new = df.dropna()

# %%
new.head()
# Out:
#     Year  Population  Ann. CO2 Em.          GDP  FF (% electricity)  \
# 10  2000     6865946       1472928  2478.218238               100.0
# 11  2001     7076728       1689104  2532.634052               100.0
# 12  2002     7295400       2110055  2570.787304               100.0
# 13  2003     7520556       2393998  2579.697807               100.0
# 14  2004     7750003       2593600  2614.212455               100.0
#
#     Carbon Intensity  Ann. CO2 Em./Unit Energy
# 10           750.000                    0.2146
# 11           666.667                    0.2162
# 12           666.667                    0.2357
# 13           714.286                    0.2303
# 14           750.000                    0.2367

# %%
corr = new.corr()

# %%
sns.heatmap(corr, annot=True)

# %%
neww = df.dropna(axis=1)

# %%
new_df = df.iloc[1:30,0:3]

# %%
new_df.shape
# Out:
# (29, 3)

# %%
new_df.head()
# Out:
#    Year  Population  Ann. CO2 Em.
# 1  1991     5149496        733234
# 2  1992     5331805        788194
# 3  1993     5521761        957646
# 4  1994     5714215       1098391
# 5  1995     5905552       1117483

# %%
neww.head()
# Out:
#    Year  Population  Ann. CO2 Em.          GDP
# 0  1990     4978489        630642  2175.208576
# 1  1991     5149496        733234  2191.840607
# 2  1992     5331805        788194  2179.507230
# 3  1993     5521761        957646  2227.353200
# 4  1994     5714215       1098391  2195.822052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      31 non-null     int64
#  1   Population                31 non-null     int64
#  2   Ann. CO2 Em.              31 non-null     int64
#  3   GDP                       31 non-null     float64
#  4   FF (% electricity)        21 non-null     float64
#  5   Carbon Intensity          21 non-null     float64
#  6   Ann. CO2 Em./Unit Energy  30 non-null     float64
# dtypes: float64(4), int64(3)
# memory usage: 1.8 KB

# %%
path3='/content/drive/MyDrive/Colab Notebooks/Assignment/DescribeOutput.xlsx'

# %%
table = df.describe()

# %%
df.describe()
# Out:
#               Year    Population  Ann. CO2 Em.          GDP  \
# count    31.000000  3.100000e+01  3.100000e+01    31.000000
# mean   2005.000000  8.181586e+06  3.273598e+06  2627.974004
# std       9.092121  2.150550e+06  2.184713e+06   330.452327
# min    1990.000000  4.978489e+06  6.306420e+05  2175.208576
# 25%    1997.500000  6.375960e+06  1.172746e+06  2347.413000
# 50%    2005.000000  7.982223e+06  2.593600e+06  2606.817449
# 75%    2012.500000  9.866924e+06  4.622682e+06  2818.376082
# max    2020.000000  1.212320e+07  7.315116e+06  3323.144451
#
#        FF (% electricity)  Carbon Intensity  Ann. CO2 Em./Unit Energy
# count           21.000000         21.000000                 30.000000
# mean            99.554857        701.905143                  0.248373
# std              1.409679         36.536022                  0.062444
# min             95.000000        650.000000                  0.212200
# 25%            100.000000        666.667000                  0.230225
# ...

# %%
table.to_excel(path3)

# %%
 dict_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Assignment/EnergyForecastDataset.xlsx', sheet_name=['Benin', 'Ghana', 'Guinea', 'Burkina Faso', 'Ivory Coast', 'Mali', 'Niger', 'Nigeria', 'Senegal'])

# %%
Nigeria_df = dict_df.get('Nigeria')

# %%
Nigeria_df.head()
# Out:
#    Year  Population  Ann. CO2 Em.         GDP   FF (% electricity)  \
# 0  1990    95212450      38857279  3259.642900                 NaN
# 1  1991    97667632      41929195  3189.089071                 NaN
# 2  1992   100161710      46265317  3253.694421                 NaN
# 3  1993   102700753      44814164  3108.674718                 NaN
# 4  1994   105293700      34934724  2977.090165                 NaN
#
#    Carbon Intensity  Ann. CO2 Em./Unit Energy
# 0               NaN                    0.1902
# 1               NaN                    0.1867
# 2               NaN                    0.2009
# 3               NaN                    0.1917
# 4               NaN                    0.1603
